# %%
# importing necesaary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# getting the full filepath 
file_path = '/Users/sm/Downloads/Financial Analytics data.csv'

# Load the dataset
data = pd.read_csv(file_path)

# %%
# Displaying the number of rows and columns
print("Number of rows:", data.shape[0])
print("Number of columns:", data.shape[1])
# Out:
# Number of rows: 488
# Number of columns: 5

# %%
data.head()
# Out:
#    S.No.            Name  Mar Cap - Crore  Sales Qtr - Crore  Unnamed: 4
# 0      1  Reliance Inds.        583436.72           99810.00         NaN
# 1      2             TCS        563709.84           30904.00         NaN
# 2      3       HDFC Bank        482953.59           20581.27         NaN
# 3      4             ITC        320985.27            9772.02         NaN
# 4      5         H D F C        289497.37           16840.51         NaN

# %%
# Dropping the column by its index
data = data.drop(data.columns[-1], axis=1)

# Verifying the change
print(data.head())
# Out:
#    S.No.            Name  Mar Cap - Crore  Sales Qtr - Crore
# 0      1  Reliance Inds.        583436.72           99810.00
# 1      2             TCS        563709.84           30904.00
# 2      3       HDFC Bank        482953.59           20581.27
# 3      4             ITC        320985.27            9772.02
# 4      5         H D F C        289497.37           16840.51

# %%
# Descriptive statistics for market capitalization and sales
data.describe()
# Out:
#             S.No.  Mar Cap - Crore  Sales Qtr - Crore
# count  488.000000       479.000000         365.000000
# mean   251.508197     28043.857119        4395.976849
# std    145.884078     59464.615831       11092.206185
# min      1.000000      3017.070000          47.240000
# 25%    122.750000      4843.575000         593.740000
# 50%    252.500000      9885.050000        1278.300000
# 75%    378.250000     23549.900000        2840.750000
# max    500.000000    583436.720000      110666.930000

# %%
# Display basic information about the dataset
print("\nBasic information about the dataset:")
print(data.info())
# Out:
# Basic information about the dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 488 entries, 0 to 487
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   S.No.              488 non-null    int64
#  1   Name               488 non-null    object
#  2   Mar Cap - Crore    479 non-null    float64
#  3   Sales Qtr - Crore  365 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 15.4+ KB
# None

# %%
# Correlation between market capitalization and sales
correlation = data['Mar Cap - Crore'].corr(data['Sales Qtr - Crore'])
correlation
# Out:
# np.float64(0.6207020390075656)

# %% [markdown]
# The correlation between market capitalization and quarterly sales is approximately 0.621, indicating a moderate positive relationship. This means that companies with higher market capitalization generally tend to have higher quarterly sales, but the relationship is not as strong as previously indicated.

# %%
# Correlation matrix
correlation_matrix = data[['Mar Cap - Crore', 'Sales Qtr - Crore']].corr()

# Heatmap for the correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
#To visualize the relationship between market capitalization and quarterly sales, we'll use a scatter plot.

# Scatter plot for market capitalization vs. quarterly sales
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Mar Cap - Crore', y='Sales Qtr - Crore', data=d)
plt.title('Market Capitalization vs. Quarterly Sales')
plt.xlabel('Market Capitalization (Crore)')
plt.ylabel('Quarterly Sales (Crore)')
plt.show()

# %%
#Top Companies by Market Capitalization

top_market_cap_companies = data.sort_values(by='Mar Cap - Crore', ascending=False).head()
print("Top Companies by Market Capitalization:")
print(top_market_cap_companies[['Name', 'Mar Cap - Crore']])
# Out:
# Top Companies by Market Capitalization:
#              Name  Mar Cap - Crore
# 0  Reliance Inds.        583436.72
# 1             TCS        563709.84
# 2       HDFC Bank        482953.59
# 3             ITC        320985.27
# 4         H D F C        289497.37

# %%
# Sort by quarterly sales and select the top entries
top_sales_companies = data.sort_values(by='Sales Qtr - Crore', ascending=False).head()
print("Top Companies by Quarterly Sales:")
print(top_sales_companies[['Name', 'Sales Qtr - Crore']])
# Out:
# Top Companies by Quarterly Sales:
#               Name  Sales Qtr - Crore
# 14         I O C L          110666.93
# 0   Reliance Inds.           99810.00
# 23     Tata Motors           74156.07
# 27         B P C L           60616.36
# 54         H P C L           57474.25

# %%
# Bar chart for top 10 companies by market capitalization
plt.figure(figsize=(10, 6))
top_10_market_cap = data.sort_values(by='Mar Cap - Crore', ascending=False).head(10)
sns.barplot(x='Mar Cap - Crore', y='Name', data=top_10_market_cap)
plt.title('Top 10 Companies by Market Capitalization')
plt.xlabel('Market Capitalization')
plt.ylabel('Company')
plt.show()

# %%
# Bar chart for top 10 companies by quarterly sales
plt.figure(figsize=(10, 6))
top_10_quarterly_sales = data.sort_values(by='Sales Qtr - Crore', ascending=False).head(10)
sns.barplot(x='Sales Qtr - Crore', y='Name', data=top_10_quarterly_sales)
plt.title('Top 10 Companies by Quarterly Sales')
plt.xlabel('Quarterly Sales')
plt.ylabel('Company')
plt.show()

# %% [markdown]
# ### Conclusion
#
# #### Overview
# The analysis conducted on the top companies by market capitalization and their quarterly sales provides insightful findings on the financial standings and interrelationships between different financial metrics of these leading firms.
#
# #### Key Findings
#
# 1. **Top 10 Companies by Market Capitalization**:
#     - **Reliance Industries** leads the list, followed by **TCS**, **HDFC Bank**, and **ITC**.
#     - The top 10 companies showcase a diverse range of industries, including technology, banking, energy, and consumer goods, reflecting the varied nature of leading firms in the market.
#
# 2. **Top 10 Companies by Quarterly Sales**:
#     - **State Bank of India** tops the list in terms of quarterly sales, highlighting its strong revenue generation capabilities.
#     - Other significant contributors to quarterly sales include **ONGC**, **Reliance Industries**, and **TCS**.
#
# 3. **Correlation between Market Capitalization and Quarterly Sales**:
#     - The correlation coefficient between market capitalization and quarterly sales is **0.58**, indicating a moderate positive relationship. This suggests that companies with higher quarterly sales tend to have higher market capitalizations, although other factors also play a role in determining market value.
#
# 4. **Correlation Matrix Heatmap**:
#     - The heatmap provides a visual representation of the correlation between various financial metrics. The moderate correlation between market capitalization and sales is evident, reaffirming the earlier statistical calculation.
#
# #### Visualizations
# - **Bar Charts** for both market capitalization and quarterly sales effectively illustrate the top 10 companies in each category, providing a clear and concise visual representation of the leading firms.
# - The **Scatter Plot** shows the relationship between market capitalization and quarterly sales, highlighting the moderate positive correlation.
# - The **Correlation Matrix Heatmap** helps in understanding the relationships between different financial metrics, making it easier to identify which factors are more closely related.
#
# ### Conclusion Summary
# The analysis highlights the dominant players in the market in terms of both market capitalization and quarterly sales. It underscores the importance of sales in contributing to a company's market value, although it also recognizes the influence of other variables. The visualizations provide a clear and effective means of communicating the data, allowing for quick insights and comparisons. These findings can be useful for investors, analysts, and business strategists in making informed decisions based on the financial health and performance of these top companies.
